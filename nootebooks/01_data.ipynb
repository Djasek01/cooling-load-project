# %% [markdown]
# # Cooling Load Prediction

# %% [markdown]
# ## 1. Razumijevanje podataka

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Učitavanje podataka

# %%
df = pd.read_csv('../data/Projekt_08_cooling_load.csv')
df.head()
# Out:
#    Relative Compactness   Surface Area   Wall Area  Roof Area  Overall Height  \
# 0                  0.98          514.5       294.0     110.25             7.0
# 1                  0.98          514.5       294.0     110.25             7.0
# 2                  0.98          514.5       294.0     110.25             7.0
# 3                  0.98          514.5       294.0     110.25             7.0
# 4                  0.90          563.5       318.5     122.50             7.0
#
#    Orientation  Glazing Area  Glazing Area Distribution  Cooling Load
# 0            2           0.0                          0         21.33
# 1            3           0.0                          0         21.33
# 2            4           0.0                          0         21.33
# 3            5           0.0                          0         21.33
# 4            2           0.0                          0         28.28

# %% [markdown]
# ### Opisivanje podataka
#     - Oblik skupa (broj instanci i atributa)

# %%
print("Oblik skupa podataka:", df.shape)
# Out:
# Oblik skupa podataka: (768, 9)

# %% [markdown]
# - Tipovi atributa

# %%
print("\nTipovi atributa:")
df.info()
# Out:
# Tipovi atributa:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Relative Compactness       768 non-null    float64
#  1    Surface Area              768 non-null    float64
#  2    Wall Area                 768 non-null    float64
#  3   Roof Area                  768 non-null    float64
#  4   Overall Height             768 non-null    float64
#  5   Orientation                768 non-null    int64
#  6   Glazing Area               768 non-null    float64
#  7   Glazing Area Distribution  768 non-null    int64
#  8   Cooling Load               768 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 54.1 KB

# %% [markdown]
# ### 4. Deskriptivna statistika
# - Prikaz svih statističkih mjera (min, max, mean, std, kvartili)

# %%
df.describe().transpose()
# Out:
#                            count        mean        std     min       25%  \
# Relative Compactness       768.0    0.764167   0.105777    0.62    0.6825
#  Surface Area              768.0  671.708333  88.086116  514.50  606.3750
#  Wall Area                 768.0  318.500000  43.626481  245.00  294.0000
# Roof Area                  768.0  176.604167  45.165950  110.25  140.8750
# Overall Height             768.0    5.250000   1.751140    3.50    3.5000
# Orientation                768.0    3.500000   1.118763    2.00    2.7500
# Glazing Area               768.0    0.234375   0.133221    0.00    0.1000
# Glazing Area Distribution  768.0    2.812500   1.550960    0.00    1.7500
# Cooling Load               768.0   24.587760   9.513306   10.90   15.6200
#
#                               50%       75%     max
# Relative Compactness         0.75    0.8300    0.98
#  Surface Area              673.75  741.1250  808.50
#  Wall Area                 318.50  343.0000  416.50
# ...

# %% [markdown]
# ### Istraživanje podataka

# %% [markdown]
# - 5.1 Distribucija svake značajke – histogrami

# %%
df.hist(figsize=(14, 10), bins=20, edgecolor='black')
plt.suptitle('Distribucija atributa', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Box-plotovi (za pregled outliera)

# %%
plt.figure(figsize=(14, 6))
df.boxplot()
plt.title('Box-plot svih atributa')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
